# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import Omi_Stats as om

# %%
df=pd.read_csv('USA_Housing.csv')

# %%
df.info()

# %%
df.describe()

# %%
for col_name in df.columns:
    print(col_name)
    st_obj=om.cal_stats(df[col_name])
    st_obj.everything()

# %%
df.isnull().sum()

# %%
x=df.drop('Price',axis=1)
y=df['Price']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test= train_test_split(x,y,test_size=0.2,random_state=555)

# %%
df.shape

# %%
print('X train Shape:',x_train.shape)
print('X test Shape:',x_test.shape)
print('y train Shape:',y_train.shape)
print('y test Shape:',y_test.shape)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(X_train,y_train)

# %%
y_pred=lr.predict(X_test)

# %%
col_index=0
for i in lr.coef_:
    print(df.columns[col_index])
    print('slope:',round(i,2))
    col_index+=1
    print('*'*30)
print('Y-intercept:',lr.intercept_)

# %%
sse=sum((y_test-y_pred)**2)
print('Sum of Squared Error:',sse)

mse= sse/len(x_test)
print('Mean Sqaure Error:',mse)

rmse= np.sqrt(mse)
print('Root Mean Square Error:',rmse)
# Out:
# Sum of Squared Error: 10012400493466.924
# Mean Sqaure Error: 10012400493.466925
# Root Mean Square Error: 100061.98325771344

# %%
from sklearn.metrics import mean_squared_error
np.sqrt(mean_squared_error(y_test,y_pred))
# Out:
# np.float64(100061.98325771344)

# %%
sns.displot(y_test-y_pred)

# %%
income=float(input('What is your Income'))
age=float(input('What is your House Age'))
rooms=float(input('What is your Number of Rooms'))
bedroom=float(input('What is your Number of Bedrooms'))
pop=float(input('What is your Area Population'))
user_input=np.array([income,age,rooms,bedroom,pop])

# %%
house_price_pred=lr.predict(user_input.reshape(1, -1))
print(f'Your house can be sold between ${round(house_price_pred[0])-50000} to ${round(house_price_pred[0])+50000}')
# Out:
# Your house can be sold between $34288740 to $34388740
# C:\Users\admin\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
pip install joblib

# %%
import joblib
joblib.dump(lr, 'usa house price pred model 100k rmse 25-08-25.pkl')
# Out:
# ['usa house price pred model 100k rmse 25-08-25.pkl']
